# %% [markdown]
# <a href="https://colab.research.google.com/github/mysteriousgirl2004/A-.-P-.-J-Abdul-Kalam-Tribute/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
import pandas as pd

# %%
Book1= pd.read_excel('/content/Book1.xlsx')

# %%
Book1
# Out:
#     YEAR               MOVIE_NAME MOVIE_TYPE  PRICE  DURATION AGE_GROUP  \
# 0   2014                 Mary Kom     Action    210      2.20       18+
# 1   1997                  Titanic  Adventure    250      3.00       18+
# 2   2023                12th Fail      Drama    300      2.26       15+
# 3   2012                    Barfi     Comedy    200      2.31       18+
# 4   2013  Yeh Jawaani hai Deewani     Comedy    180      2.00       18+
# 5   2018                    Sanju      Drama    280      3.00       10+
# 6   2014                       PK     Comedy    300      2.50       10+
# 7   2009                 3 Idiots     Comedy    350      2.90       10+
# 8   2013                   Frozen    Fantasy    250      1.42        5+
# 9   2013              After Earth     Action    190      1.50       18+
# 10  2002               Spider Man     Action    330      3.00       15+
# 11  2001             Harry Potter    Fantasy    370      3.00       15+
# ...

# %%
Book1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YEAR           18 non-null     int64
#  1   MOVIE_NAME     18 non-null     object
#  2   MOVIE_TYPE     18 non-null     object
#  3   PRICE          18 non-null     int64
#  4   DURATION       18 non-null     float64
#  5   AGE_GROUP      18 non-null     object
#  6   NO_OF_VIEWERS  18 non-null     int64
#  7   RATING         18 non-null     float64
#  8   PROFIT         18 non-null     float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.4+ KB

# %%
from matplotlib import pyplot as plt

# %%
plt.stem(Book1['PRICE'],Book1['PROFIT'])
plt.xlabel('PRICE')
plt.ylabel('PROFIT')
# Out:
# Text(0, 0.5, 'PROFIT')

# %%
plt.bar(Book1['MOVIE_TYPE'],Book1['AGE_GROUP'])
plt.xlabel('MOVIE_TYPE')
plt.ylabel('AGE_GROUP')
# Out:
# Text(0, 0.5, 'AGE_GROUP')

# %%
plt.scatter(Book1['DURATION'],Book1['PRICE'],c = Book1['DURATION'])
plt.xlabel('DURATION')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %%
plt.plot(Book1['YEAR'],Book1['MOVIE_NAME'])
plt.xlabel('YEAR')
plt.ylabel('MOVIE_NAME')
# Out:
# Text(0, 0.5, 'MOVIE_NAME')

# %%
plt.bar(Book1['NO_OF_VIEWERS'],Book1['RATING'])
plt.xlabel('NO_OF_VIEWERS')
plt.ylabel('RATING')
# Out:
# Text(0, 0.5, 'RATING')

# %%
plt.bar(Book1['DURATION'],Book1['MOVIE_NAME'])
plt.xlabel('DURATION')
plt.ylabel('MOVIE_NAME')
# Out:
# Text(0, 0.5, 'MOVIE_NAME')
